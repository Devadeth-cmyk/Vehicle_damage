# %% [markdown]
# <a href="https://colab.research.google.com/github/kiransree2002/vehicle-damage-insurance-ai/blob/main/damage_detection_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Libraries

# %%
# !pip install ultralytics opencv-python-headless pyyaml -q
import os, shutil, time
import yaml
import random
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 7.6 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.

# %% [markdown]
# # Read Dataset

# %%
DRIVE_PROJECT_ROOT = '/content/drive/MyDrive/AI ML/Projects/CARDD_YOLO'
LOCAL_PROJECT_ROOT = '/content/CARDD_YOLO'

assert os.path.isdir(DRIVE_PROJECT_ROOT), f'Drive dataset not found at {DRIVE_PROJECT_ROOT} — update the path'

if os.path.isdir(LOCAL_PROJECT_ROOT):
    print('Local copy already exists at', LOCAL_PROJECT_ROOT, '— skipping copy. Delete it first if you want to re-copy.')
else:
    print('Copying dataset from Drive to local disk — this happens once per session...')
    start = time.time()
    shutil.copytree(DRIVE_PROJECT_ROOT, LOCAL_PROJECT_ROOT)
    print(f'Copy complete in {time.time() - start:.1f} seconds')

PROJECT_ROOT = LOCAL_PROJECT_ROOT
yaml_path = f'{PROJECT_ROOT}/data.yaml'
# Out:
# Copying dataset from Drive to local disk — this happens once per session...
# Copy complete in 194.0 seconds

# %% [markdown]
# ##Validate the Local Dataset

# %%
print('YOLO dataset root (local):', PROJECT_ROOT)
print('data.yaml exists:', os.path.exists(yaml_path))

for split in ['train', 'val', 'test']:
    image_dir = f'{PROJECT_ROOT}/images/{split}'
    label_dir = f'{PROJECT_ROOT}/labels/{split}'
    if os.path.isdir(image_dir) and os.path.isdir(label_dir):
        print(f'{split}: images={len(os.listdir(image_dir))}, labels={len(os.listdir(label_dir))}')
    else:
        print(f'{split}: NOT FOUND (image_dir exists={os.path.isdir(image_dir)}, label_dir exists={os.path.isdir(label_dir)})')
# Out:
# YOLO dataset root (local): /content/CARDD_YOLO
# data.yaml exists: True
# train: images=1620, labels=2191
# val: images=810, labels=655
# test: images=374, labels=374

# %%
assert os.path.exists(yaml_path), 'data.yaml not found in local copy'

with open(yaml_path, 'r') as f:
    data_yaml = yaml.safe_load(f)

# data.yaml paths must point to LOCAL paths now, not Drive — rewrite and save a local version
data_yaml['train'] = f'{PROJECT_ROOT}/images/train'
data_yaml['val'] = f'{PROJECT_ROOT}/images/val'
if os.path.isdir(f'{PROJECT_ROOT}/images/test'):
    data_yaml['test'] = f'{PROJECT_ROOT}/images/test'

with open(yaml_path, 'w') as f:
    yaml.safe_dump(data_yaml, f)

print('data.yaml contents (paths rewritten to local disk):')
print(data_yaml)

assert os.path.isdir(f'{PROJECT_ROOT}/images/train'), 'Training images folder not found'
assert os.path.isdir(f'{PROJECT_ROOT}/labels/train'), 'Training labels folder not found'
print('\nLocal dataset is ready for training.')
# Out:
# data.yaml contents (paths rewritten to local disk):
# {'path': '/content/drive/MyDrive/AI ML/Projects/CARDD_YOLO', 'train': '/content/CARDD_YOLO/images/train', 'val': '/content/CARDD_YOLO/images/val', 'test': '/content/CARDD_YOLO/images/test', 'names': ['dent', 'scratch', 'crack', 'glass shatter', 'lamp broken', 'tire flat']}
#
# Local dataset is ready for training.

# %% [markdown]
# ##Detecting Label Format

# %%
label_dir = f'{PROJECT_ROOT}/labels/train'
label_files = [f for f in os.listdir(label_dir) if f.endswith('.txt')]
sample_files = random.sample(label_files, min(20, len(label_files)))

line_lengths = []
for fname in sample_files:
    with open(os.path.join(label_dir, fname)) as f:
        for line in f:
            parts = line.strip().split()
            if parts:
                line_lengths.append(len(parts))

if not line_lengths:
    raise ValueError('No label content found — check that label .txt files are not empty')

max_len = max(line_lengths)
is_segmentation = max_len > 5

print(f'Sampled {len(sample_files)} label files, {len(line_lengths)} annotation lines')
print(f'Max fields per line: {max_len}')
print(f'Detected format: {"SEGMENTATION (polygon masks)" if is_segmentation else "DETECTION (bounding boxes)"}')

MODEL_NAME = 'yolov8n-seg.pt' if is_segmentation else 'yolov8n.pt'
print(f'\nModel to use: {MODEL_NAME}')
# Out:
# Sampled 20 label files, 43 annotation lines
# Max fields per line: 5
# Detected format: DETECTION (bounding boxes)
#
# Model to use: yolov8n.pt

# %% [markdown]
# ##Image Checking

# %%
img_dir = f'{PROJECT_ROOT}/images/train'
img_files = [f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
sample_img_name = random.choice(img_files)
sample_label_name = os.path.splitext(sample_img_name)[0] + '.txt'

img = cv2.imread(os.path.join(img_dir, sample_img_name))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

label_path = os.path.join(label_dir, sample_label_name)
if os.path.exists(label_path):
    with open(label_path) as f:
        for line in f:
            parts = line.strip().split()
            if not parts:
                continue
            cls = int(parts[0])
            coords = list(map(float, parts[1:]))
            if is_segmentation:
                pts = [(int(coords[i]*w), int(coords[i+1]*h)) for i in range(0, len(coords), 2)]
                for i in range(len(pts)):
                    cv2.line(img, pts[i], pts[(i+1) % len(pts)], (255, 0, 0), 2)
            else:
                xc, yc, bw, bh = coords
                x1 = int((xc - bw/2) * w)
                y1 = int((yc - bh/2) * h)
                x2 = int((xc + bw/2) * w)
                y2 = int((yc + bh/2) * h)
                cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 0), 2)

plt.figure(figsize=(8, 8))
plt.imshow(img)
plt.title(sample_img_name)
plt.axis('off')
plt.show()

# %% [markdown]
# #Model Training

# %%
model = YOLO(MODEL_NAME)

results = model.train(
    data = yaml_path,
    epochs = 30,
    imgsz = 640,
    batch = 16,
    device = 0,
    project = '/content/runs',
    name = 'car_damage_yolov8',
    patience = 10
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 84.0MB/s 0.1s
# Ultralytics 8.4.152 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/CARDD_YOLO/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=car_damage_yolov8, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/car_damage_yolov8, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 22.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, 16, None, [64, 128, 256]]
# Model summary: 129 layers, 3,012,018 parameters, 3,012,002 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: downloading yolo26n.pt for AMP checks (one-time, not used for training)...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'weights/yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 88.4MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2529.8±1375.5 MB/s, size: 701.7 KB)
# train: Scanning /content/CARDD_YOLO/labels/train... 1567 images, 53 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1620/1620 1.5Kit/s 1.1s
# train: New cache created: /content/CARDD_YOLO/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 86.8±37.7 MB/s, size: 618.6 KB)
# val: Scanning /content/CARDD_YOLO/labels/val... 655 images, 155 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 810/810 299.2it/s 2.7s
# val: New cache created: /content/CARDD_YOLO/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs
/s 34.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 1.9it/s 13.8s
#                    all        810       1428      0.469      0.614      0.475       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      2.71G      1.101      1.374      1.338          5        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 37.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 2.0it/s 13.2s
#                    all        810       1428      0.485      0.561      0.459      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      2.71G      1.094      1.325      1.318         16        640: 100% ━━━━━━━━━━━━ 102/102 3.0it/s 34.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 1.9it/s 14.0s
#                    all        810       1428      0.507      0.597      0.495      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      2.71G      1.042      1.257      1.289         15        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 1.9it/s 13.4s
#                    all        810       1428      0.472      0.629      0.495      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.71G      1.049      1.226      1.289          8        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 37.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 1.8it/s 14.4s
#                    all        810       1428      0.479      0.622      0.498      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      2.71G      1.007      1.183      1.258          6        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 34.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 1.8it/s 14.1s
#                    all        810       1428       0.48      0.646       0.49      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      2.71G     0.9954      1.153      1.257         10        640: 100% ━━━━━━━━━━━━ 102/102 2.9it/s 35.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 1.9it/s 13.5s
#                    all        810       1428      0.505      0.593      0.501      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      2.71G     0.9839      1.127      1.238         10        640: 100% ━━━━━━━━━━━━ 102/102 2.8it/s 36.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 1.9it/s 13.6s
#                    all        810       1428      0.496      0.622      0.496      0.372
#
# 30 epochs completed in 0.451 hours.
# Optimizer stripped from /content/runs/car_damage_yolov8/weights/last.pt, 6.2MB
# Optimizer stripped from /content/runs/car_damage_yolov8/weights/best.pt, 6.2MB
#
# Validating /content/runs/car_damage_yolov8/weights/best.pt...
# Ultralytics 8.4.152 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 1.7it/s 15.0s
#                    all        810       1428        0.5      0.609      0.498      0.374
#                   dent        285        408      0.471      0.439      0.375      0.194
#                scratch        364        619      0.468      0.459      0.409      0.217
#                  crack        102        154      0.346      0.227      0.189     0.0907
#          glass shatter        108        108      0.773      0.972      0.829       0.77
#            lamp broken        109        110      0.533        0.8      0.661      0.537
#              tire flat         28         29      0.407      0.759      0.527      0.439
# Speed: 0.2ms preprocess, 4.6ms inference, 0.0ms loss, 3.5ms postprocess per image
# Results saved to /content/runs/car_damage_yolov8

# %%
## Resume training if a session disconnects mid-run
# last_ckpt = '/content/runs/car_damage_yolov8/weights/last.pt'
# model = YOLO(last_ckpt)
# results = model.train(resume=True)

# %% [markdown]
# #Evaluation

# %%
best_model_path_local = '/content/runs/car_damage_yolov8/weights/best.pt'
trained_model = YOLO(best_model_path_local)

metrics = trained_model.val()

print('Box mAP50-95:', metrics.box.map)
print('Box mAP50:', metrics.box.map50)
if hasattr(metrics, 'seg') and metrics.seg is not None:
    print('Seg mAP50-95:', metrics.seg.map)
    print('Seg mAP50:', metrics.seg.map50)

print('\nPer-class results:')
names_iter = data_yaml.get('names', {}).items() if isinstance(data_yaml.get('names'), dict) else enumerate(data_yaml.get('names', []))
for i, name in names_iter:
    try:
        print(f'  {name}: mAP50-95 = {metrics.box.maps[i]:.3f}')
    except Exception:
        pass
# Out:
# Ultralytics 8.4.152 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5112.1±1013.0 MB/s, size: 765.0 KB)
# val: Scanning /content/CARDD_YOLO/labels/val.cache... 655 images, 155 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 810/810 261.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 3.2it/s 15.7s
#                    all        810       1428      0.496        0.6      0.496      0.373
#                   dent        285        408      0.473       0.44      0.376      0.194
#                scratch        364        619      0.471      0.454      0.408      0.218
#                  crack        102        154      0.344      0.225      0.185     0.0879
#          glass shatter        108        108      0.766      0.963      0.822      0.764
#            lamp broken        109        110      0.531        0.8       0.67      0.547
#              tire flat         28         29      0.395      0.719      0.517      0.426
# Speed: 2.0ms preprocess, 5.1ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to /content/runs/detect/val
# Box mAP50-95: 0.3726839279255176
# Box mAP50: 0.49644218887302793
#
# Per-class results:
#   dent: mAP50-95 = 0.194
#   scratch: mAP50-95 = 0.218
#   crack: mAP50-95 = 0.088
#   glass shatter: mAP50-95 = 0.764
#   lamp broken: mAP50-95 = 0.547
#   tire flat: mAP50-95 = 0.426

# %%
# Copy final weights and best model to Google drive
drive_runs_dest = f'{DRIVE_PROJECT_ROOT}/runs/car_damage_yolov8'

os.makedirs(os.path.dirname(drive_runs_dest), exist_ok=True)
if os.path.isdir(drive_runs_dest):
    shutil.rmtree(drive_runs_dest)

print('Copying trained model + logs to Drive (one-time write)...')
shutil.copytree('/content/runs/car_damage_yolov8', drive_runs_dest)

best_model_path = f'{drive_runs_dest}/weights/best.pt'
print('Saved to Drive at:', best_model_path)
# Out:
# Copying trained model + logs to Drive (one-time write)...
# Saved to Drive at: /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/runs/car_damage_yolov8/weights/best.pt

# %% [markdown]
# #Testing

# %%
# Testing on sample images
test_img_dir = f'{PROJECT_ROOT}/images/test'
if os.path.isdir(test_img_dir) and len(os.listdir(test_img_dir)) > 0:
    test_img_name = random.choice(os.listdir(test_img_dir))
    test_img_path = os.path.join(test_img_dir, test_img_name)
else:
    val_img_dir = f'{PROJECT_ROOT}/images/val'
    test_img_name = random.choice(os.listdir(val_img_dir))
    test_img_path = os.path.join(val_img_dir, test_img_name)

print('Running inference on:', test_img_path)
results = trained_model(test_img_path)
results[0].show()
# Out:
# Running inference on: /content/CARDD_YOLO/images/test/001282.jpg
#
# image 1/1 /content/CARDD_YOLO/images/test/001282.jpg: 448x640 1 scratch, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=1000x667>

# %%
# Final Model path
print('Trained model permanently saved at (Drive):')
print(best_model_path)
# Out:
# Trained model permanently saved at (Drive):
# /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/runs/car_damage_yolov8/weights/best.pt

# %% [markdown]
# #Severity Estimation

# %%
SEVERITY_WEIGHTS = {
    'scratch': 1,
    'dent': 3,
    'crack': 4,
    'glass_shatter': 5,
    'lamp_broken': 3,
    'tire_flat': 5,
}

def estimate_severity(results, img_w, img_h, class_names):

    boxes = results.boxes
    if boxes is None or len(boxes) == 0:
        return {
            'severity_score': 0.0,
            'severity_label': 'no damage detected',
            'details': []
        }

    total_score = 0.0
    details = []
    img_area = img_w * img_h

    for box in boxes:
        cls_id = int(box.cls[0])
        cls_name = class_names[cls_id] if isinstance(class_names, list) else class_names.get(cls_id, str(cls_id))
        conf = float(box.conf[0])

        # bounding box area relative to full image (0 to 1)
        x1, y1, x2, y2 = box.xyxy[0].tolist()
        box_area = (x2 - x1) * (y2 - y1)
        area_ratio = box_area / img_area

        weight = SEVERITY_WEIGHTS.get(cls_name, 2)  # default weight = 2 for unknown classes
        contribution = weight * area_ratio * conf

        total_score += contribution
        details.append({
            'class': cls_name,
            'confidence': round(conf, 3),
            'area_ratio': round(area_ratio, 4),
            'contribution': round(contribution, 4)
        })

    # Normalize score to 0-10 scale (tune the multiplier based on real data)
    normalized_score = min(total_score * 20, 10)

    if normalized_score < 3:
        label = 'minor'
    elif normalized_score < 6:
        label = 'moderate'
    else:
        label = 'severe'

    return {
        'severity_score': round(normalized_score, 2),
        'severity_label': label,
        'details': details
    }

# %%
test_img_path = "/content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test"
results = trained_model(test_img_path)
r = results[0]

img_h, img_w = r.orig_shape
class_names = data_yaml['names']

severity_result = estimate_severity(r, img_w, img_h, class_names)

print('Severity Score:', severity_result['severity_score'], '/ 10')
print('Severity Label:', severity_result['severity_label'])
print('\nDetection Details:')
for d in severity_result['details']:
    print(d)
# Out:
# image 1/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000012.jpg: 448x640 1 tire flat, 6.9ms
# image 2/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000015.jpg: 448x640 1 scratch, 6.1ms
# image 3/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000023.jpg: 448x640 (no detections), 7.5ms
# image 4/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000033.jpg: 640x448 4 dents, 75.1ms
# image 5/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000040.jpg: 448x640 1 scratch, 7.7ms
# image 6/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000042.jpg: 448x640 1 lamp broken, 6.0ms
# image 7/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000044.jpg: 448x640 1 dent, 6.0ms
# image 8/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000057.jpg: 448x640 1 tire flat, 6.1ms
# image 9/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000082.jpg: 448x640 1 scratch, 6.2ms
# image 10/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000088.jpg: 480x640 (no detections), 40.1ms
# image 11/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000090.jpg: 480x640 2 glass shatters, 5.8ms
# image 12/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000106.jpg: 448x640 1 lamp broken, 6.8ms
# image 13/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000128.jpg: 640x448 2 dents, 7.0ms
# image 14/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000152.jpg: 448x640 1 dent, 1 lamp broken, 7.5ms
# image 15/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000165.jpg: 448x640 1 glass shatter, 6.4ms
# image 16/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000175.jpg: 448x640 1 glass shatter, 6.2ms
# image 17/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000185.jpg: 448x640 1 glass shatter, 6.4ms
# image 18/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000191.jpg: 640x448 2 dents, 2 cracks, 1 lamp broken, 6.9ms
# image 19/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000204.jpg: 448x640 1 glass shatter, 6.9ms
# image 20/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000214.jpg: 448x640 1 glass shatter, 8.4ms
# image 21/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000224.jpg: 448x640 1 glass shatter, 7.6ms
# image 22/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000233.jpg: 480x640 1 glass shatter, 7.2ms
# image 23/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000237.jpg: 448x640 4 dents, 1 scratch, 2 lamp brokens, 1 tire flat, 6.9ms
# image 24/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000253.jpg: 448x640 1 glass shatter, 6.4ms
# image 25/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000267.jpg: 448x640 1 dent, 1 glass shatter, 6.4ms
# image 26/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000288.jpg: 480x640 2 dents, 2 glass shatters, 7.0ms
# image 27/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000293.jpg: 448x640 1 scratch, 1 lamp broken, 8.4ms
# image 28/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000297.jpg: 448x640 1 lamp broken, 6.0ms
# image 29/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000310.jpg: 384x640 1 glass shatter, 39.7ms
# image 30/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000320.jpg: 448x640 1 glass shatter, 7.0ms
# image 31/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000330.jpg: 448x640 1 glass shatter, 6.0ms
# image 32/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000340.jpg: 448x640 1 glass shatter, 6.3ms
# image 33/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000348.jpg: 448x640 2 scratchs, 6.2ms
# image 34/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000353.jpg: 416x640 (no detections), 41.3ms
# image 35/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000387.jpg: 480x640 1 lamp broken, 7.2ms
# image 36/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000400.jpg: 448x640 1 scratch, 7.4ms
# image 37/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000404.jpg: 448x640 1 dent, 2 scratchs, 1 lamp broken, 6.4ms
# image 38/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000415.jpg: 480x640 1 dent, 6.7ms
# image 39/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000422.jpg: 448x640 2 dents, 1 scratch, 6.7ms
# image 40/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000424.jpg: 448x640 1 scratch, 6.3ms
# image 41/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000433.jpg: 448x640 2 dents, 1 glass shatter, 6.0ms
# image 42/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000452.jpg: 448x640 1 dent, 6.2ms
# image 43/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000466.jpg: 448x640 1 glass shatter, 6.3ms
# image 44/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000468.jpg: 448x640 2 dents, 3 scratchs, 6.2ms
# image 45/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000481.jpg: 448x640 2 scratchs, 6.2ms
# image 46/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000488.jpg: 480x640 2 scratchs, 6.8ms
# image 47/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000513.jpg: 448x640 1 dent, 3 cracks, 1 glass shatter, 6.9ms
# image 48/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000514.jpg: 480x640 2 dents, 4 scratchs, 1 crack, 12.9ms
# image 49/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000520.jpg: 448x640 2 dents, 1 crack, 6.8ms
# image 50/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000541.jpg: 480x640 1 dent, 2 scratchs, 1 lamp broken, 6.7ms
# image 51/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000550.jpg: 640x448 4 cracks, 6.8ms
# image 52/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000565.jpg: 480x640 1 glass shatter, 6.8ms
# image 53/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000567.jpg: 640x384 2 scratchs, 41.6ms
# image 54/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000570.jpg: 640x448 2 dents, 7.0ms
# image 55/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000589.jpg: 448x640 1 tire flat, 7.0ms
# image 56/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000603.jpg: 448x640 (no detections), 5.9ms
# image 57/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000611.jpg: 448x640 1 dent, 1 lamp broken, 6.0ms
# image 58/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000625.jpg: 448x640 3 dents, 1 scratch, 6.0ms
# image 59/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000638.jpg: 448x640 2 scratchs, 6.0ms
# image 60/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000648.jpg: 480x640 2 scratchs, 1 lamp broken, 6.6ms
# image 61/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000659.jpg: 512x640 1 tire flat, 38.2ms
# image 62/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000670.jpg: 448x640 1 tire flat, 6.5ms
# image 63/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000687.jpg: 480x640 1 scratch, 6.7ms
# image 64/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000693.jpg: 640x448 1 crack, 1 glass shatter, 6.5ms
# image 65/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000696.jpg: 448x640 1 scratch, 1 lamp broken, 6.5ms
# image 66/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000698.jpg: 448x640 1 dent, 2 scratchs, 1 glass shatter, 1 lamp broken, 6.1ms
# image 67/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000702.jpg: 448x640 1 dent, 6.1ms
# image 68/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000720.jpg: 448x640 (no detections), 5.8ms
# image 69/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000730.jpg: 448x640 3 scratchs, 1 tire flat, 5.8ms
# image 70/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000740.jpg: 480x640 4 scratchs, 1 tire flat, 7.0ms
# image 71/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000749.jpg: 448x640 (no detections), 6.4ms
# image 72/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000766.jpg: 384x640 4 scratchs, 6.4ms
# image 73/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000778.jpg: 640x448 (no detections), 6.4ms
# image 74/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000787.jpg: 448x640 1 glass shatter, 6.4ms
# image 75/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/000796.jpg: 448x640 2 scratchs, 5.8ms
# image 76/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/
374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003573.jpg: 448x640 1 scratch, 6.2ms
# image 335/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003586.jpg: 448x640 2 scratchs, 6.0ms
# image 336/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003589.jpg: 448x640 1 scratch, 6.9ms
# image 337/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003612.jpg: 480x640 4 scratchs, 6.8ms
# image 338/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003626.jpg: 448x640 (no detections), 6.5ms
# image 339/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003634.jpg: 448x640 2 scratchs, 6.2ms
# image 340/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003649.jpg: 480x640 1 scratch, 6.8ms
# image 341/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003656.jpg: 448x640 1 scratch, 6.6ms
# image 342/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003671.jpg: 512x640 (no detections), 8.7ms
# image 343/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003683.jpg: 384x640 2 scratchs, 7.0ms
# image 344/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003690.jpg: 448x640 2 dents, 1 scratch, 8.2ms
# image 345/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003695.jpg: 480x640 2 scratchs, 7.3ms
# image 346/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003703.jpg: 480x640 1 scratch, 6.5ms
# image 347/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003720.jpg: 448x640 1 glass shatter, 6.5ms
# image 348/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003734.jpg: 448x640 (no detections), 5.8ms
# image 349/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003743.jpg: 448x640 2 dents, 1 scratch, 6.3ms
# image 350/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003748.jpg: 448x640 1 glass shatter, 5.9ms
# image 351/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003768.jpg: 448x640 1 glass shatter, 1 lamp broken, 6.1ms
# image 352/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003782.jpg: 448x640 1 glass shatter, 6.0ms
# image 353/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003789.jpg: 448x640 1 lamp broken, 8.4ms
# image 354/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003793.jpg: 448x640 1 glass shatter, 6.0ms
# image 355/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003804.jpg: 448x640 1 glass shatter, 6.2ms
# image 356/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003812.jpg: 448x640 1 glass shatter, 6.0ms
# image 357/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003823.jpg: 448x640 1 glass shatter, 6.0ms
# image 358/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003829.jpg: 480x640 2 dents, 1 scratch, 8.2ms
# image 359/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003831.jpg: 448x640 1 dent, 6.9ms
# image 360/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003842.jpg: 480x640 3 scratchs, 7.4ms
# image 361/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003872.jpg: 352x640 (no detections), 6.7ms
# image 362/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003879.jpg: 448x640 1 dent, 9.6ms
# image 363/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003887.jpg: 448x640 1 glass shatter, 6.9ms
# image 364/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003905.jpg: 448x640 1 glass shatter, 5.9ms
# image 365/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003908.jpg: 448x640 2 dents, 2 scratchs, 6.4ms
# image 366/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003925.jpg: 480x640 2 dents, 3 scratchs, 1 glass shatter, 1 lamp broken, 6.8ms
# image 367/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003935.jpg: 480x640 2 dents, 6.6ms
# image 368/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003948.jpg: 448x640 2 dents, 1 crack, 2 lamp brokens, 13.2ms
# image 369/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003956.jpg: 416x640 1 dent, 2 scratchs, 6.8ms
# image 370/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003959.jpg: 480x640 1 glass shatter, 7.3ms
# image 371/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003977.jpg: 448x640 1 glass shatter, 6.9ms
# image 372/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003992.jpg: 448x640 1 dent, 1 scratch, 6.3ms
# image 373/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003993.jpg: 448x640 1 glass shatter, 6.4ms
# image 374/374 /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/images/test/003994.jpg: 448x640 1 crack, 6.3ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Severity Score: 3.26 / 10
# Severity Label: moderate
#
# Detection Details:
# {'class': 'tire flat', 'confidence': 0.417, 'area_ratio': 0.1957, 'contribution': 0.1632}

# %%
test_img_dir = f'{PROJECT_ROOT}/images/test'
if os.path.isdir(test_img_dir) and len(os.listdir(test_img_dir)) > 0:
    test_img_name = random.choice(os.listdir(test_img_dir))
    test_img_path = os.path.join(test_img_dir, test_img_name)
else:
    val_img_dir = f'{PROJECT_ROOT}/images/val'
    test_img_name = random.choice(os.listdir(val_img_dir))
    test_img_path = os.path.join(val_img_dir, test_img_name)

# %%
results = trained_model(test_img_path)
r = results[0]

img_h, img_w = r.orig_shape
class_names = data_yaml['names']

severity_result = estimate_severity(r, img_w, img_h, class_names)

print('Severity Score:', severity_result['severity_score'], '/ 10')
print('Severity Label:', severity_result['severity_label'])
# Out:
# image 1/1 /content/CARDD_YOLO/images/test/001993.jpg: 448x640 1 dent, 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# Severity Score: 8.4 / 10
# Severity Label: severe

# %% [markdown]
# #Batch report

# %%
import pandas as pd

def batch_severity_report(img_dir, model, class_names, max_images=50):
    img_files = [f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    img_files = random.sample(img_files, min(max_images, len(img_files)))

    rows = []
    for fname in img_files:
        path = os.path.join(img_dir, fname)
        res = model(path, verbose=False)[0]
        h, w = res.orig_shape
        sev = estimate_severity(res, w, h, class_names)
        rows.append({
            'image': fname,
            'severity_score': sev['severity_score'],
            'severity_label': sev['severity_label'],
            'num_detections': len(sev['details'])
        })

    return pd.DataFrame(rows)

val_dir = f'{PROJECT_ROOT}/images/val'
report_df = batch_severity_report(val_dir, trained_model, data_yaml['names'], max_images=30)

print(report_df.sort_values('severity_score', ascending=False))

# Report Drive-il save cheyyan
report_path = f'{DRIVE_PROJECT_ROOT}/severity_report.csv'
report_df.to_csv(report_path, index=False)
print('\nSaved report to:', report_path)
# Out:
#          image  severity_score      severity_label  num_detections
# 7   000294.jpg           10.00              severe               2
# 24  003292.jpg           10.00              severe               1
# 19  003614.jpg           10.00              severe               3
# 21  000322.jpg           10.00              severe               1
# 16  002280.jpg           10.00              severe               4
# 17  000331.jpg           10.00              severe               2
# 27  000272.jpg           10.00              severe               2
# 25  000655.jpg           10.00              severe               3
# 5   001079.jpg            9.67              severe               2
# 28  000470.jpg            9.32              severe               1
# 29  000578.jpg            8.73              severe               4
# 1   002102.jpg            7.93              severe               5
# 2   002449.jpg            5.52            moderate               1
# 20  003876.jpg            5.43            moderate               2
# 4   000928.jpg            5.07            moderate               8
# 14  000542.jpg            5.03            moderate               4
# 3   000990.jpg            4.21            moderate               4
# 22  002861.jpg            3.93            moderate               3
# 0   002154.jpg            3.53            moderate               2
# 11  003498.jpg            3.27            moderate               3
# 6   000013.jpg            2.91               minor               1
# 15  000017.jpg            2.03               minor               1
# 8   000748.jpg            1.63               minor               1
# 23  001192.jpg            1.61               minor               3
# 18  000130.jpg            1.30               minor               1
# 26  003475.jpg            1.12               minor               2
# 13  002817.jpg            0.65               minor               3
# 12  002579.jpg            0.00  no damage detected               0
# 9   003274.jpg            0.00  no damage detected               0
# 10  001185.jpg            0.00  no damage detected               0
#
# Saved report to: /content/drive/MyDrive/AI ML/Projects/CARDD_YOLO/severity_report.csv
